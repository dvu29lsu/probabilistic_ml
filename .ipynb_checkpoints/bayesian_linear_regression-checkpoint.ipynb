# %%
## in this repo we trying modelling the linear regression using the Bayesian approach

# %%
# In this notebook i will use the diabetes dataset from sklearn to model
# https://scikit-learn.org/stable/datasets/toy_dataset.html#diabetes-dataset
# we will compare the Bayesian method with the Gaussian Process method

import numpy as np
from scipy.stats import multivariate_normal
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load the diabetes data from sklearn

from sklearn.datasets import load_diabetes

data = load_diabetes()

# %%
# feature
X = pd.DataFrame(data.data, columns=data.feature_names)
# data
y = pd.Series(data.target, name='disease_progression')

# %%
X.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
y
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: disease_progression, Length: 442, dtype: float64

# %% [markdown]
# ## Modeling using the synthetic data

# %%
## for proofing the concept of the bayesian regresison we can generate a linear data
x = np.ones([200,2])
# x = np.linspace(-1,1,200)
x[:,0] = np.linspace(-1,1,200)
# x[:,1] = np.linspace(-3,3, 200)

# %%
x
# Out:
# array([[-1.        ,  1.        ],
#        [-0.98994975,  1.        ],
#        [-0.9798995 ,  1.        ],
#        [-0.96984925,  1.        ],
#        [-0.95979899,  1.        ],
#        [-0.94974874,  1.        ],
#        [-0.93969849,  1.        ],
#        [-0.92964824,  1.        ],
#        [-0.91959799,  1.        ],
#        [-0.90954774,  1.        ],
#        [-0.89949749,  1.        ],
#        [-0.88944724,  1.        ],
#        [-0.87939698,  1.        ],
#        [-0.86934673,  1.        ],
#        [-0.85929648,  1.        ],
#        [-0.84924623,  1.        ],
#        [-0.83919598,  1.        ],
#        [-0.82914573,  1.        ],
#        [-0.81909548,  1.        ],
#        [-0.80904523,  1.        ],
#        [-0.79899497,  1.        ],
#        [-0.78894472,  1.        ],
#        [-0.77889447,  1.        ],
#        [-0.76884422,  1.        ],
#        [-0.75879397,  1.        ],
#        [-0.74874372,  1.        ],
#        [-0.73869347,  1.        ],
#        [-0.72864322,  1.        ],
#        [-0.71859296,  1.        ],
#        [-0.70854271,  1.        ],
#        [-0.69849246,  1.        ],
#        [-0.68844221,  1.        ],
#        [-0.67839196,  1.        ],
#        [-0.66834171,  1.        ],
#        [-0.65829146,  1.        ],
#        [-0.64824121,  1.        ],
#        [-0.63819095,  1.        ],
#        [-0.6281407 ,  1.        ],
#        [-0.61809045,  1.        ],
#        [-0.6080402 ,  1.        ],
#        [-0.59798995,  1.        ],
#        [-0.5879397 ,  1.        ],
#        [-0.57788945,  1.        ],
#        [-0.5678392 ,  1.        ],
#        [-0.55778894,  1.        ],
#        [-0.54773869,  1.        ],
#        [-0.53768844,  1.        ],
#        [-0.52763819,  1.        ],
#        [-0.51758794,  1.        ],
#        [-0.50753769,  1.        ],
#        [-0.49748744,  1.        ],
#        [-0.48743719,  1.        ],
#        [-0.47738693,  1.        ],
#        [-0.46733668,  1.        ],
#        [-0.45728643,  1.        ],
#        [-0.44723618,  1.        ],
#        [-0.43718593,  1.        ],
#        [-0.42713568,  1.        ],
#        [-0.41708543,  1.        ],
#        [-0.40703518,  1.        ],
#        [-0.39698492,  1.        ],
#        [-0.38693467,  1.        ],
#        [-0.37688442,  1.        ],
#        [-0.36683417,  1.        ],
#        [-0.35678392,  1.        ],
#        [-0.34673367,  1.        ],
#        [-0.33668342,  1.        ],
#        [-0.32663317,  1.        ],
#        [-0.31658291,  1.        ],
#        [-0.30653266,  1.        ],
#        [-0.29648241,  1.        ],
#        [-0.28643216,  1.        ],
#        [-0.27638191,  1.        ],
#        [-0.26633166,  1.        ],
#        [-0.25628141,  1.        ],
#        [-0.24623116,  1.        ],
#        [-0.2361809 ,  1.        ],
#        [-0.22613065,  1.        ],
#        [-0.2160804 ,  1.        ],
#        [-0.20603015,  1.        ],
#        [-0.1959799 ,  1.        ],
#        [-0.18592965,  1.        ],
#        [-0.1758794 ,  1.        ],
#        [-0.16582915,  1.        ],
#        [-0.15577889,  1.        ],
#        [-0.14572864,  1.        ],
#        [-0.13567839,  1.        ],
#        [-0.12562814,  1.        ],
#        [-0.11557789,  1.        ],
#        [-0.10552764,  1.        ],
#        [-0.09547739,  1.        ],
#        [-0.08542714,  1.        ],
#        [-0.07537688,  1.        ],
#        [-0.06532663,  1.        ],
#        [-0.05527638,  1.        ],
#        [-0.04522613,  1.        ],
#        [-0.03517588,  1.        ],
#        [-0.02512563,  1.        ],
#        [-0.01507538,  1.        ],
#        [-0.00502513,  1.        ],
#        [ 0.00502513,  1.        ],
#        [ 0.01507538,  1.        ],
#        [ 0.02512563,  1.        ],
#        [ 0.03517588,  1.        ],
#        [ 0.04522613,  1.        ],
#        [ 0.05527638,  1.        ],
#        [ 0.06532663,  1.        ],
#        [ 0.07537688,  1.        ],
#        [ 0.08542714,  1.        ],
#        [ 0.09547739,  1.        ],
#        [ 0.10552764,  1.        ],
#        [ 0.11557789,  1.        ],
#        [ 0.12562814,  1.        ],
#        [ 0.13567839,  1.        ],
#        [ 0.14572864,  1.        ],
#        [ 0.15577889,  1.        ],
#        [ 0.16582915,  1.        ],
#        [ 0.1758794 ,  1.        ],
#        [ 0.18592965,  1.        ],
#        [ 0.1959799 ,  1.        ],
#        [ 0.20603015,  1.        ],
#        [ 0.2160804 ,  1.        ],
#        [ 0.22613065,  1.        ],
#        [ 0.2361809 ,  1.        ],
#        [ 0.24623116,  1.        ],
#        [ 0.25628141,  1.        ],
#        [ 0.26633166,  1.        ],
#        [ 0.27638191,  1.        ],
#        [ 0.28643216,  1.        ],
#        [ 0.29648241,  1.        ],
#        [ 0.30653266,  1.        ],
#        [ 0.31658291,  1.        ],
#        [ 0.32663317,  1.        ],
#        [ 0.33668342,  1.        ],
#        [ 0.34673367,  1.        ],
#        [ 0.35678392,  1.        ],
#        [ 0.36683417,  1.        ],
#        [ 0.37688442,  1.        ],
#        [ 0.38693467,  1.        ],
#        [ 0.39698492,  1.        ],
#        [ 0.40703518,  1.        ],
#        [ 0.41708543,  1.        ],
#        [ 0.42713568,  1.        ],
#        [ 0.43718593,  1.        ],
#        [ 0.44723618,  1.        ],
#        [ 0.45728643,  1.        ],
#        [ 0.46733668,  1.        ],
#        [ 0.47738693,  1.        ],
#        [ 0.48743719,  1.        ],
#        [ 0.49748744,  1.        ],
#        [ 0.50753769,  1.        ],
#        [ 0.51758794,  1.        ],
#        [ 0.52763819,  1.        ],
#        [ 0.53768844,  1.        ],
#        [ 0.54773869,  1.        ],
#        [ 0.55778894,  1.        ],
#        [ 0.5678392 ,  1.        ],
#        [ 0.57788945,  1.        ],
#        [ 0.5879397 ,  1.        ],
#        [ 0.59798995,  1.        ],
#        [ 0.6080402 ,  1.        ],
#        [ 0.61809045,  1.        ],
#        [ 0.6281407 ,  1.        ],
#        [ 0.63819095,  1.        ],
#        [ 0.64824121,  1.        ],
#        [ 0.65829146,  1.        ],
#        [ 0.66834171,  1.        ],
#        [ 0.67839196,  1.        ],
#        [ 0.68844221,  1.        ],
#        [ 0.69849246,  1.        ],
#        [ 0.70854271,  1.        ],
#        [ 0.71859296,  1.        ],
#        [ 0.72864322,  1.        ],
#        [ 0.73869347,  1.        ],
#        [ 0.74874372,  1.        ],
#        [ 0.75879397,  1.        ],
#        [ 0.76884422,  1.        ],
#        [ 0.77889447,  1.        ],
#        [ 0.78894472,  1.        ],
#        [ 0.79899497,  1.        ],
#        [ 0.80904523,  1.        ],
#        [ 0.81909548,  1.        ],
#        [ 0.82914573,  1.        ],
#        [ 0.83919598,  1.        ],
#        [ 0.84924623,  1.        ],
#        [ 0.85929648,  1.        ],
#        [ 0.86934673,  1.        ],
#        [ 0.87939698,  1.        ],
#        [ 0.88944724,  1.        ],
#        [ 0.89949749,  1.        ],
#        [ 0.90954774,  1.        ],
#        [ 0.91959799,  1.        ],
#        [ 0.92964824,  1.        ],
#        [ 0.93969849,  1.        ],
#        [ 0.94974874,  1.        ],
#        [ 0.95979899,  1.        ],
#        [ 0.96984925,  1.        ],
#        [ 0.9798995 ,  1.        ],
#        [ 0.98994975,  1.        ],
#        [ 1.        ,  1.        ]])

# %%
# set the variance for the model
sigma = 0.3 ## noise
mu = 0 ## noise mean

# set the linear model weight
w = np.array([[-1.3, 0.5]])

# %%
# calculate the y value

y = x @ w.T + np.random.normal(mu, sigma, x[:,0:1].shape)

# %%
y
# Out:
# array([[ 1.50888657],
#        [ 1.59037154],
#        [ 1.65153458],
#        [ 2.34898146],
#        [ 2.01919568],
#        [ 1.73883012],
#        [ 1.36790342],
#        [ 1.83177539],
#        [ 1.59698808],
#        [ 1.34798275],
#        [ 2.0937293 ],
#        [ 1.63273137],
#        [ 1.67840307],
#        [ 1.71402872],
#        [ 1.06409293],
#        [ 1.8477987 ],
#        [ 1.46754503],
#        [ 1.25045154],
#        [ 1.88033726],
#        [ 1.49828296],
#        [ 2.1661959 ],
#        [ 1.2671789 ],
#        [ 1.64873542],
#        [ 1.4401076 ],
#        [ 1.22903173],
#        [ 1.59781354],
#        [ 1.16528377],
#        [ 1.3286188 ],
#        [ 1.28073219],
#        [ 1.58000746],
#        [ 1.35098204],
#        [ 1.62222426],
#        [ 0.93252573],
#        [ 1.10458   ],
#        [ 1.77110949],
#        [ 1.11761706],
#        [ 1.50200415],
#        [ 1.48398914],
#        [ 2.25639168],
#        [ 1.34599947],
#        [ 1.40900419],
#        [ 0.84665712],
#        [ 1.73592871],
#        [ 1.36476714],
#        [ 1.3166243 ],
#        [ 1.07844574],
#        [ 0.92939426],
#        [ 1.02642351],
#        [ 1.22749738],
#        [ 1.14184692],
#        [ 1.23201129],
#        [ 1.00785032],
#        [ 0.88039543],
#        [ 0.92110058],
#        [ 1.05296398],
#        [ 1.00078603],
#        [ 1.36523251],
#        [ 1.4380031 ],
#        [ 1.21863899],
#        [ 1.06818605],
#        [ 1.30512624],
#        [ 1.12345527],
#        [ 1.25193275],
#        [ 1.13156966],
#        [ 0.81477562],
#        [ 0.93930781],
#        [ 0.38156691],
#        [ 1.11245068],
#        [ 1.35601418],
#        [ 1.5734498 ],
#        [ 0.41682005],
#        [ 0.7012938 ],
#        [ 0.8825429 ],
#        [ 1.10612856],
#        [ 0.71010078],
#        [ 0.32250264],
#        [ 0.70658224],
#        [ 0.82793192],
#        [ 1.17498971],
#        [ 0.61455976],
#        [ 1.14104397],
#        [ 0.82825649],
#        [ 0.43154959],
#        [ 1.05001425],
#        [ 0.89897386],
#        [ 0.9579582 ],
#        [ 1.06468957],
#        [ 0.72981643],
#        [ 0.43642783],
#        [ 0.53560408],
#        [ 0.4723643 ],
#        [ 0.73113148],
#        [ 0.90184929],
#        [ 0.64833832],
#        [ 0.70911002],
#        [ 0.47509099],
#        [ 0.63762966],
#        [ 0.20922501],
#        [ 0.98140259],
#        [ 0.07728107],
#        [ 0.86156759],
#        [ 0.49993658],
#        [ 0.85266822],
#        [ 1.01448712],
#        [ 0.39675038],
#        [-0.21782773],
#        [ 0.74774608],
#        [ 0.87989149],
#        [ 0.77132796],
#        [ 0.07213728],
#        [ 0.23594892],
#        [ 0.06403322],
#        [ 0.42214417],
#        [ 0.18113437],
#        [ 0.08036892],
#        [ 0.26319403],
#        [ 0.71566004],
#        [-0.11948711],
#        [ 0.97532076],
#        [ 0.38833855],
#        [ 0.70884439],
#        [ 0.29385035],
#        [-0.49615398],
#        [ 0.19756195],
#        [ 0.53582947],
#        [-0.39643977],
#        [ 0.04267177],
#        [ 0.50019322],
#        [-0.55089847],
#        [-0.02474325],
#        [ 0.01505268],
#        [ 0.69563283],
#        [-0.23921715],
#        [ 0.5194802 ],
#        [-0.01100323],
#        [ 0.23877682],
#        [ 0.43896854],
#        [ 0.19762206],
#        [-0.0189846 ],
#        [ 0.1737898 ],
#        [-0.01811028],
#        [-0.51271497],
#        [ 0.33094503],
#        [-0.1594687 ],
#        [-0.13333324],
#        [-0.21071878],
#        [ 0.37647392],
#        [-0.43470953],
#        [-0.17909942],
#        [-0.04995872],
#        [ 0.08252973],
#        [-0.47878475],
#        [-0.24773833],
#        [ 0.34558319],
#        [-0.25670587],
#        [-0.08873274],
#        [ 0.18550138],
#        [-0.60715797],
#        [-0.61808782],
#        [-0.53507576],
#        [-0.30385457],
#        [-0.20949287],
#        [-0.2109876 ],
#        [-0.73203887],
#        [-0.42521665],
#        [-0.68491993],
#        [-0.28590456],
#        [ 0.21124466],
#        [-0.85903829],
#        [-0.64562702],
#        [-0.35614901],
#        [-0.54214551],
#        [-0.75507761],
#        [-0.01651874],
#        [-0.51419829],
#        [-0.48551885],
#        [ 0.07475886],
#        [ 0.13732071],
#        [-0.16561924],
#        [-0.45187532],
#        [-0.48837823],
#        [-0.67344385],
#        [-0.44479461],
#        [-0.51437179],
#        [-1.02066789],
#        [-0.59948608],
#        [-0.9036837 ],
#        [-0.38710802],
#        [-0.82713735],
#        [-0.95924425],
#        [-0.75953339],
#        [-0.59807052],
#        [-0.81100834],
#        [-1.04418708],
#        [-0.23269727],
#        [-0.53939282],
#        [-1.09012092],
#        [-0.9935167 ],
#        [-0.41593112],
#        [-0.90850288]])

# %%
## plot the data
plt.figure(figsize=(6,6))
plt.scatter(x[:, 0], y)

# %%
## we starting modeling the bayesian regresison model with the prior with the sigma 0.5

tau = 0.5
prior_variance = tau * np.eye(w.shape[1])
prior_weight = multivariate_normal(mean=[0,0],cov=prior_variance)

# %%
prior_variance
# Out:
# array([[0.5, 0. ],
#        [0. , 0.5]])

# %%
# function for plot distribution over the weight space

def plot_over_w(dist, title):
    w0, w1 = np.mgrid[-3:2:0.01, -2:3:0.01] #generate the distribution of the weight
    pos = np.empty([w0.shape[0], w0.shape[0], 2])
    pos[:,:, 0] = w0
    pos[:,:, 1] = w1
    plt.contour(w0, w1, dist.pdf(pos))
    plt.xlabel("w_0", fontsize=15)
    plt.ylabel("w_1", fontsize=15)
    plt.title(title, fontsize=15)

# %%
plot_over_w(prior_weight, "prior_over_weight")

# %%
#function that sample "posible line" from the distribution and plot them with the input/output data

# firstly we sample the line

def sample_lines(x, y, m, s):
    w = np.random.multivariate_normal(m.flatten(), cov = s)
    return x @ w[:, np.newaxis]

def plot_lines(x, y, m, s, N):
    lines = np.array([sample_lines(x, y, m, s) for _ in range(N)]) #sample N lines from the posterior
    
    # plot the line
    plt.plot(x[:, 0], lines[:,:, 0].T, 'r')
    
    #plot true data
    plt.plot(x[:, 0], y, marker='o', linestyle='none', color='green')

    plt.xlabel("x", fontsize=16)
    plt.ylabel("y", fontsize=16)

# %%
plot_lines(x, y, np.array([0,0]), prior_variance, 20)

# %%
# calculate the posterior distribution P(W|X,Y) based on the prior we have calculated previously,
def posterior(x, y):
    tI = tau * np.identity(x.shape[1])
    m_n = np.linalg.inv((x.T @ x)/sigma + tI) @ x.T @ y / sigma
    s_n_inv = (x.T @ x)/sigma + tI
    s_n = np.linalg.inv(s_n_inv)
    return m_n, s_n

# %%
# visualize the posterior over W and sample some function with this posterior

## calculate the posteriror
m, s = posterior(x, y)
posterior_w = multivariate_normal(mean=m.flatten(), cov = s)

# sample function from the posterior
plot_lines(x, y, m, s, N = 10)

# %%
# plot the posterior over f
plot_over_w(posterior_w, "posterior over weight")

# %%
print("\n-----Mean and covariance of posterior for all data points-----")
print("mean: [%.2f, %.2f]" % (m[0], m[1]))
print("covariance: ")
print(s)
# Out:
# -----Mean and covariance of posterior for all data points-----
# mean: [-1.30, 0.53]
# covariance:
# [[0.00444532 0.        ]
#  [0.         0.00149888]]
# C:\Users\longv\AppData\Local\Temp\ipykernel_10460\3618639270.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("mean: [%.2f, %.2f]" % (m[0], m[1]))

# %%
fig = plt.figure(figsize=(12, 12))
plt.subplots_adjust(wspace=0.3, hspace=0.5)

import pprint
pp = pprint.PrettyPrinter(indent=4)

num_data_points = [10, 50, 200]
for index, i in enumerate(num_data_points):
    # calculate posterior for i data points
    m, s = posterior(x[:i-1], y[:i-1])
    posterior_w = multivariate_normal(mean=m.flatten(), cov=s)
    
    print("\n-----Mean and covariance of posterior for %i data points-----" % i)
    print("mean: [%.2f, %.2f]" % (m[0], m[1]))
    print("covariance: ")
    print(s)
    
    # sample from posterior and plot "possible" lines
    plt.subplot(len(num_data_points), 2, 2*index+1)
    plot_lines(x[:i-1, :], y[:i-1], m, s, N=10) 
    
    # plot posterior over w
    plt.subplot(len(num_data_points), 2, 2*index+2)
    plot_over_w(posterior_w, 'Posterior (%d data points)' % i)
# Out:
# -----Mean and covariance of posterior for 10 data points-----
# mean: [-0.85, 0.91]
# covariance:
# [[1.02747717 0.97000481]
#  [0.97000481 0.94853408]]
#
# -----Mean and covariance of posterior for 50 data points-----
# mean: [-1.07, 0.68]
# covariance:
# [[0.24470306 0.18511254]
#  [0.18511254 0.14613737]]
#
# -----Mean and covariance of posterior for 200 data points-----
# mean: [-1.30, 0.53]
# covariance:
# [[4.51252256e-03 2.26589132e-05]
#  [2.26589132e-05 1.50651599e-03]]
# C:\Users\longv\AppData\Local\Temp\ipykernel_10460\4260546911.py:14: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("mean: [%.2f, %.2f]" % (m[0], m[1]))
